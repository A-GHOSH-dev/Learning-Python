# %%
#pandas- variance

import pandas as pd
df = pd.read_excel('sample.xlsx')
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   WBC_area         10 non-null     int64
#  1   WBC_convex_area  10 non-null     int64
#  2   WBC_peri         10 non-null     float64
#  3   ecc_wbc          10 non-null     float64
#  4   solidity_wbc     10 non-null     float64
#  5   orient_wbc       10 non-null     float64
#  6   nuc_area         10 non-null     int64
#  7   nuc_ratio        10 non-null     float64
#  8   peri_nuc         10 non-null     float64
#  9   round_nuc        10 non-null     float64
#  10  ecc_nuc          10 non-null     float64
#  11  solidity_nuc     10 non-null     float64
#  12  convex_area_nuc  10 non-null     int64
#  13  avg_cyt_re       10 non-null     float64
#  14  avg_cyt_gr       10 non-null     float64
#  15  avg_cyt_bl       10 non-null     float64
# ...

# %%
#remove duplicates
df.drop_duplicates(inplace = True)
df
# Out:
#    WBC_area  WBC_convex_area    WBC_peri   ecc_wbc  solidity_wbc  orient_wbc  \
# 0      3798             3849  244.485281  0.580090      0.986750  -79.012451
# 1      3521             3590  236.727922  0.602939      0.980780   77.502581
# 2      2805             2805  208.000000  0.374387      1.000000    0.000000
# 3      2595             2616  200.242641  0.433734      0.991972   77.086906
# 4      2662             2704  209.313708  0.239700      0.984467  -33.831764
# 5      2769             2783  205.656854  0.259973      0.994969  -43.866516
# 6      3099             3326  237.941125  0.699188      0.931750  -79.950037
# 7      3848             3895  243.556349  0.446128      0.987933  -58.649271
# 8      2947             3073  217.012193  0.419289      0.958998  -85.255857
# 9      2668             2717  200.870058  0.432532      0.981965   36.693518
#
#    nuc_area  nuc_ratio    peri_nuc  round_nuc  ...  convex_area_nuc  \
# ...

# %%
#Adding new column to existing DataFrame
#gender = [‘M’,’M’,’M’,’F’,’M’,’M’,’M’,’F’,’M’,’F’]
#df[‘Gender’] = gender
#df.head()
#Multiple Criteria Filtering
df.loc[(df['WBC_area']>=3000) & (df['WBC_peri']> 210)]
# Out:
#    WBC_area  WBC_convex_area    WBC_peri   ecc_wbc  solidity_wbc  orient_wbc  \
# 0      3798             3849  244.485281  0.580090      0.986750  -79.012451
# 1      3521             3590  236.727922  0.602939      0.980780   77.502581
# 6      3099             3326  237.941125  0.699188      0.931750  -79.950037
# 7      3848             3895  243.556349  0.446128      0.987933  -58.649271
#
#    nuc_area  nuc_ratio    peri_nuc  round_nuc  ...  convex_area_nuc  \
# 0      2720   0.716166  237.764502   0.604623  ...             2993
# 1      2373   0.673956  204.066017   0.716088  ...             2555
# 6      2139   0.690223  212.994949   0.592491  ...             2490
# 7      2664   0.692308  224.308658   0.665353  ...             2933
#
#    avg_cyt_re  avg_cyt_gr  avg_cyt_bl  entropy_cyt  minoraxis  majoraxis  \
# 0  124.895176  114.916512  145.590909   -18.413519  63.942810  78.500533
# 1  140.402439  129.554878  155.895470   -17.749720  60.959837  76.411145
# ...

# %%
#Sorting
df.sort_values(by=['ecc_wbc'])
#Saving data frame(df) to excel file
df.to_excel('sample1.xlsx')
df.to_csv('office_output.csv')
# Out:
#    WBC_area  WBC_convex_area    WBC_peri   ecc_wbc  solidity_wbc  orient_wbc  \
# 0      3798             3849  244.485281  0.580090      0.986750  -79.012451
# 1      3521             3590  236.727922  0.602939      0.980780   77.502581
# 2      2805             2805  208.000000  0.374387      1.000000    0.000000
# 3      2595             2616  200.242641  0.433734      0.991972   77.086906
# 4      2662             2704  209.313708  0.239700      0.984467  -33.831764
# 5      2769             2783  205.656854  0.259973      0.994969  -43.866516
# 6      3099             3326  237.941125  0.699188      0.931750  -79.950037
# 7      3848             3895  243.556349  0.446128      0.987933  -58.649271
# 8      2947             3073  217.012193  0.419289      0.958998  -85.255857
# 9      2668             2717  200.870058  0.432532      0.981965   36.693518
#
#    nuc_area  nuc_ratio    peri_nuc  round_nuc  ...  convex_area_nuc  \
# ...

# %%
#concat 2 sheets
sheet1 = pd.read_excel('sample.xlsx', sheet_name = 0, index_col = 0)

sheet2 = pd.read_excel('sample.xlsx',sheet_name = 1, index_col = 0)
  
newData = pd.concat([sheet1, sheet2])
newData
# Out:
#           WBC_convex_area    WBC_peri   ecc_wbc  solidity_wbc  orient_wbc  \
# WBC_area
# 3798                 3849  244.485281  0.580090      0.986750  -79.012451
# 3521                 3590  236.727922  0.602939      0.980780   77.502581
# 2805                 2805  208.000000  0.374387      1.000000    0.000000
# 2595                 2616  200.242641  0.433734      0.991972   77.086906
# 2662                 2704  209.313708  0.239700      0.984467  -33.831764
# 2769                 2783  205.656854  0.259973      0.994969  -43.866516
# 3099                 3326  237.941125  0.699188      0.931750  -79.950037
# 3848                 3895  243.556349  0.446128      0.987933  -58.649271
# 2947                 3073  217.012193  0.419289      0.958998  -85.255857
# 2668                 2717  200.870058  0.432532      0.981965   36.693518
# 3038                 3194  226.284271  0.564423      0.951158   85.174753
# ...

# %%
newData.head()
# Out:
#           WBC_convex_area    WBC_peri   ecc_wbc  solidity_wbc  orient_wbc  \
# WBC_area
# 3798                 3849  244.485281  0.580090      0.986750  -79.012451
# 3521                 3590  236.727922  0.602939      0.980780   77.502581
# 2805                 2805  208.000000  0.374387      1.000000    0.000000
# 2595                 2616  200.242641  0.433734      0.991972   77.086906
# 2662                 2704  209.313708  0.239700      0.984467  -33.831764
#
#           nuc_area  nuc_ratio    peri_nuc  round_nuc   ecc_nuc  ...  \
# WBC_area                                                        ...
# 3798          2720   0.716166  237.764502   0.604623  0.672656  ...
# 3521          2373   0.673956  204.066017   0.716088  0.717206  ...
# 2805          1976   0.704456  173.195959   0.827792  0.442008  ...
# 2595          1912   0.736802  176.267027   0.773313  0.560308  ...
# 2662          2025   0.760706  168.024387   0.901343  0.181265  ...
#
# ...

# %%
newData.tail()
# Out:
#           WBC_convex_area    WBC_peri   ecc_wbc  solidity_wbc  orient_wbc  \
# WBC_area
# 2864                 2901  210.727922  0.556178      0.987246   73.012862
# 2600                 2600  200.000000  0.274670      1.000000   90.000000
# 2632                 2644  201.656854  0.610025      0.995461    4.068234
# 2058                 2058  178.000000  0.515079      1.000000   90.000000
# 2514                 2557  197.313708  0.440528      0.983183   44.319834
#
#           nuc_area  nuc_ratio    peri_nuc  round_nuc   ecc_nuc  ...  \
# WBC_area                                                        ...
# 2864          1422   0.496508  434.516811   0.089653  0.705701  ...
# 2600          1818   0.699231  183.580736   0.677875  0.502288  ...
# 2632          1810   0.687690  173.781746   0.753148  0.672771  ...
# 2058          1547   0.751701  148.710678   0.879055  0.559435  ...
# 2514          1754   0.697693  199.237590   0.547663  0.296715  ...
#
# ...

# %%
newData.shape
# Out:
# (19, 21)

# %%
newData['WBC_peri'].mean()
# Out:
# 213.23088780799492

# %%
df["WBC_peri"].var()
# Out:
# 331.5385413247946

# %%
df['WBC_peri'].corr(df['peri_nuc'])
# Out:
# 0.936231512108168

# %%
df.corr()
# Out:
#                  WBC_area  WBC_convex_area  WBC_peri   ecc_wbc  solidity_wbc  \
# WBC_area         1.000000         0.991062  0.935565  0.557404     -0.062928
# WBC_convex_area  0.991062         1.000000  0.969090  0.630335     -0.195329
# WBC_peri         0.935565         0.969090  1.000000  0.703744     -0.366927
# ecc_wbc          0.557404         0.630335  0.703744  1.000000     -0.603632
# solidity_wbc    -0.062928        -0.195329 -0.366927 -0.603632      1.000000
# orient_wbc      -0.307833        -0.358059 -0.420105 -0.026253      0.424668
# nuc_area         0.970072         0.952219  0.871829  0.439952     -0.001171
# nuc_ratio       -0.695588        -0.718919 -0.763419 -0.699240      0.237624
# peri_nuc         0.927190         0.950899  0.936232  0.721875     -0.296091
# round_nuc       -0.752188        -0.809208 -0.843108 -0.886591      0.513744
# ecc_nuc          0.531308         0.594588  0.602003  0.904535     -0.541377
# ...
